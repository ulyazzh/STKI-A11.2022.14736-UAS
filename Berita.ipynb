# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
data_tidakvalid = pd.read_csv("tidakvalid.csv")
data_valid = pd.read_csv("beritavalid2.csv")

# %%
data_tidakvalid.head()
# Out:
#                                                judul  \
# 0  Pemerintah Menggratiskan Listrik Seluruh Indon...
# 1  NASA Umumkan Penemuan Kehidupan di Mars Setela...
# 2  Hewan Peliharaan Anda Diam-Diam Memata-Matai A...
# 3  Kejadian Aneh: Sungai di Sumatera Berubah Menj...
# 4  Kimia Farma Bagikan Hadiah Uang Tunai Rp 2 Jut...
#
#                                               narasi         label
# 0  Dalam pengumuman yang mengejutkan, pemerintah ...  Berita Palsu
# 1  Berita yang menghebohkan dunia sains, NASA dik...  Berita Palsu
# 2  Sebuah teori baru menyebutkan bahwa hewan peli...  Berita Palsu
# 3  Penduduk setempat melaporkan fenomena luar bia...  Berita Palsu
# 4  Pesan berantai di media sosial menyebutkan bah...  Berita Palsu

# %%
data_valid.head(5)
# Out:
#                                                judul  \
# 0  Penutupan Sementara Masjid Al Jabbar Diperpanj...
# 1          Gempa M 4,4 Guncang Jailolo, Maluku Utara
# 2  KPK Sita Rp5,6 Miliar dari Eks Bupati Sidoarjo...
# 3  Ketua RW Plumpang Bantah Ada Pipa Pertamina Me...
# 4  Transaksi Janggal Rp300 Triliun di Kemenkeu Ve...
#
#                                               narasi         label
# 0    Pemerintah Daerah Jawa Barat memperpanjang p...  Berita Valid
# 1    Gempa bumi bermagnitudo 4,4 mengguncang Jail...  Berita Valid
# 2    Komisi Pemberantasan Korupsi (KPK) menyita u...  Berita Valid
# 3    Ketua RW 09 Kelurahan Rawa Badak Selatan, Ko...  Berita Valid
# 4    Menteri Koordinator Bidang Politik, Hukum, d...  Berita Valid

# %%
data_tidakvalid["class"] = 0
data_valid["class"] = 1

# %%
data_tidakvalid.shape, data_valid.shape
# Out:
# ((2143, 4), (2328, 4))

# %%
# Menghapus 10 baris terakhir untuk pengujian manual dan membuat salinan
data_tidakvalid_manual_testing = data_tidakvalid.tail(10).copy()
for i in range(4, 7, -1):
    data_tidakvalid.drop([i], axis=0, inplace=True)

data_valid_manual_testing = data_valid.tail(10).copy()
for i in range(73, 76, -1):
    data_valid.drop([i], axis=0, inplace=True)

# Menetapkan kolom class
data_tidakvalid_manual_testing["class"] = 0
data_valid_manual_testing["class"] = 1

# %%
data_tidakvalid.shape, data_valid.shape
# Out:
# ((2143, 4), (2328, 4))

# %%
data_tidakvalid_manual_testing["class"] = 0
data_valid_manual_testing["class"] = 1

# %%
data_tidakvalid_manual_testing.head(10)
# Out:
#                                                   judul  \
# 2133  Tiba tiba jadi spt....mau ngemis suara muslim....
# 2134  Foto Massa Sudah Tumpah Ruah Mengepung Gedung ...
# 2135                       Racun Dari Nasi di Magic Com
# 2136  Lindungilah Saudara Muslim Kami di Rohingya da...
# 2137  Foto Beserta Video Pesawat Tempur dan Rudal Is...
data_manual_testing.to_csv("manual_testing.csv")

# %%
data_merge = pd.concat([data_tidakvalid, data_valid], axis =0 )
data_merge.head(10)
# Out:
#                                                judul  \
# 0  Pemerintah Menggratiskan Listrik Seluruh Indon...
# 1  NASA Umumkan Penemuan Kehidupan di Mars Setela...
# 2  Hewan Peliharaan Anda Diam-Diam Memata-Matai A...
# 3  Kejadian Aneh: Sungai di Sumatera Berubah Menj...
# 4  Kimia Farma Bagikan Hadiah Uang Tunai Rp 2 Jut...
# 5  Air Minum Dalam Kemasan Ternyata Mengandung Za...
# 6  Restoran Ini Menawarkan Makanan Gratis Tapi Ad...
# 7  Vaksin COVID-19 Mengandung Microchip untuk Men...
# 8  Ilmuwan Temukan Formula Obat yang Membuat Manu...
# 9  Organisasi Rahasia Akan Mengontrol Dunia denga...
#
#                                               narasi         label  class
# 0  Dalam pengumuman yang mengejutkan, pemerintah ...  Berita Palsu      0
# 1  Berita yang menghebohkan dunia sains, NASA dik...  Berita Palsu      0
# 2  Sebuah teori baru menyebutkan bahwa hewan peli...  Berita Palsu      0
# 3  Penduduk setempat melaporkan fenomena luar bia...  Berita Palsu      0
# 4  Pesan berantai di media sosial menyebutkan bah...  Berita Palsu      0
# 5  Menurut laporan tidak resmi, air minum dalam k...  Berita Palsu      0
# 6  Sebuah restoran di Jakarta dikabarkan memberik...  Berita Palsu      0
# 7  Teori konspirasi yang kembali mencuat menyatak...  Berita Palsu      0
# 8  Dalam klaim yang kontroversial, sekelompok ilm...  Berita Palsu      0
# 9  Kabar tentang organisasi rahasia yang akan men...  Berita Palsu      0

# %%
data_merge.columns
# Out:
# Index(['judul', 'narasi', 'label', 'class'], dtype='object')

# %%
data = data_merge.drop(["judul", "label"], axis = 1)

# %%
data.isnull().sum()
# Out:
# narasi    0
# class     0
# dtype: int64

# %%
data = data.sample(frac = 1)

# %%
data.head()
# Out:
#                                                  narasi  class
# 1314                    “Firing squads kill 4 convicts”      1
# 2011  Kapolres Deliserdang, AKBP Eddy Suryantha Tari...      0
# 1383  Tak sempat di tepis…!!! Ratusan rudal Au5tr4al...      0
# 556   FITNAH INI MENGGELIKAN, TAPI TIDAK BISA DIDIAM...      0
# 1650  Video yang harus ditonton, situasi sebenarnya ...      1

# %%
data.reset_index(inplace = True)
data.drop(["index"], axis = 1, inplace = True)

# %%
data.columns
# Out:
# Index(['narasi', 'class'], dtype='object')

# %%
data.head()
# Out:
#                                               narasi  class
# 0                    “Firing squads kill 4 convicts”      1
# 1  Kapolres Deliserdang, AKBP Eddy Suryantha Tari...      0
# 2  Tak sempat di tepis…!!! Ratusan rudal Au5tr4al...      0
# 3  FITNAH INI MENGGELIKAN, TAPI TIDAK BISA DIDIAM...      0
# 4  Video yang harus ditonton, situasi sebenarnya ...      1

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)  # Menghapus teks dalam kurung siku
    text = re.sub(r'\s+', ' ', text)  # Mengganti spasi berlebih dengan satu spasi
    text = re.sub(r'https?://\S+', '', text)  # Menghapus URL
    text = re.sub(r'\*+', '', text)  # Menghapus tanda bintang
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)  # Menghapus tanda baca
    text = re.sub(r'\n', '', text)  # Menghapus karakter baris baru
    text = re.sub(r'\w*\d\w*', '', text)  # Menghapus kata dengan angka
    return text

# %%
print(data.columns)
data["narasi"] = data["narasi"].apply(wordopt)
# Out:
# Index(['narasi', 'class'], dtype='object')

# %%
x = data["narasi"]
y = data["class"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.667262969588551

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.62      0.63       515
#            1       0.69      0.70      0.70       603
#
#     accuracy                           0.67      1118
#    macro avg       0.66      0.66      0.66      1118
# weighted avg       0.67      0.67      0.67      1118

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)
DT.score(xv_test, y_test)
# Out:
# 0.5697674418604651

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.57      0.55       515
#            1       0.61      0.57      0.59       603
#
#     accuracy                           0.57      1118
#    macro avg       0.57      0.57      0.57      1118
# weighted avg       0.57      0.57      0.57      1118

# %%
from sklearn.ensemble import GradientBoostingClassifier

GBC = GradientBoostingClassifier(random_state=0)
GBC.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gbc = GBC.predict(xv_test)
GBC.score(xv_test, y_test)
# Out:
# 0.6198568872987478

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.70      0.63       515
#            1       0.68      0.55      0.61       603
#
#     accuracy                           0.62      1118
#    macro avg       0.63      0.63      0.62      1118
# weighted avg       0.63      0.62      0.62      1118

# %%
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier(random_state=0)
RFC.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rfc = RFC.predict(xv_test)
RFC.score(xv_test, y_test)
# Out:
# 0.6457960644007156

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.63       515
#            1       0.68      0.65      0.66       603
#
#     accuracy                           0.65      1118
#    macro avg       0.64      0.65      0.64      1118
# weighted avg       0.65      0.65      0.65      1118

# %%
def output_lable(n):
    if n == 0:
        return "Berita Tidak Valid"
    elif n == 1:
        return "Berita Valid"

def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_GBC = GBC.predict(new_xv_test)
    pred_RFC = RFC.predict(new_xv_test)

    return print("\n\nLR Prediction: {} \nDT Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(output_lable(pred_LR[0]),                                                                                                       output_lable(pred_DT[0]),
                                                                                                              output_lable(pred_GBC[0]),
                                                                                                              output_lable(pred_RFC[0])))

# %%
news = str(input())
manual_testing(news)
# Out:
#  Pemberitaan media di Malaysia menyebutkan bahwa asap tebal yang tengah mengepung negara mereka berasal dari Indonesia. Menanggapi hal tersebut, pihak Pemerintah Indonesia memberikan bantahannya. Badan Metereologi Klimatologi dan Geofisika (BMKG) membantah asap yang menyelimuti wilayah Sarawak, Malaysia, berasal dari kebakaran hutan dan lahan di Indonesia. Asap yang muncul di wilayah tersebut diduga berasal dari local hotspot.
# LR Prediction: Berita Valid
# DT Prediction: Berita Tidak Valid
# GBC Prediction: Berita Tidak Valid
# RFC Prediction: Berita Tidak Valid

# %%
news = str(input())
manual_testing(news)
# Out:
#  Penyebar Hoaks dan Penghina Prabowo dan Habib Rizieq Dibekuk
# LR Prediction: Berita Tidak Valid
# DT Prediction: Berita Tidak Valid
# GBC Prediction: Berita Tidak Valid
# RFC Prediction: Berita Tidak Valid

# %%
news = str(input())
manual_testing(news)
# Out:
#  Menteri Koordinator bidang Hukum, Hak Asasi Manusia (HAM), Imigrasi dan Pemasyarakatan Yusril Ihza Mahendra mengatakan pemerintah menghormati putusan Mahkamah Konstitusi (MK) yang menghapus persentase pengusulan pasangan calon presiden dan wakil presiden (presidential threshold). MK menyatakan Pasal 222 Undang-undang Nomor 7 Tahun 2017 tentang Pemilihan Umum (UU Pemilu) bertentangan dengan konstitusi.  "Ses